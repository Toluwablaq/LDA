# %%
pwd
# Out:
# 'c:\\Users\\Toluwa\\Desktop\\Classification'

# %%
import pandas as pd
import sklearn  
import numpy
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df=pd.read_csv("c:/Users/Toluwa/Desktop/Classification/Waterdataset.csv")
df.head()
# Out:
#         date        ph  turbidity       solids  chromium  conductivity  \
# 0   1/1/2018  9.445130   3.875165  13168.52916      0.83    592.659021
# 1   1/3/2018  9.024845   3.985251  19859.67648      0.68    451.143481
# 2   1/6/2018       NaN   2.747313  23403.63730      0.53    475.573562
# 3   1/9/2018  6.800119   3.854940  39143.40333      0.03    376.456593
# 4  1/10/2018  7.174135   3.939896  20401.10246      0.69    315.549900
#
#      hardness  potability
# 0  145.805402           1
# 1  128.096691           1
# 2  169.974849           1
# 3  242.008082           1
# 4  203.408935           1

# %%
df.describe()
#df.shape
# Out:
#                ph   turbidity        solids    chromium  conductivity  \
# count  779.000000  912.000000    912.000000  873.000000    912.000000
# mean     7.331521    3.945447  22137.352221    0.718706    426.752222
# std      2.494979    0.787613   8888.852675    0.329021     81.667253
# min      0.227499    1.812529   2808.025756    0.010000    210.319182
# 25%      5.996849    3.421016  15338.539553    0.460000    364.512390
# 50%      7.160467    3.938100  21284.713075    0.880000    421.086049
# 75%      8.335468    4.475458  27776.360457    1.000000    482.607998
# max     52.519126    6.494249  56351.396300    1.000000    695.369528
#
#          hardness  potability
# count  912.000000  912.000000
# mean   197.987917    0.512061
# std     34.165580    0.500129
# min     47.432000    0.000000
# 25%    178.213958    0.000000
# 50%    199.067577    1.000000
# 75%    218.243182    1.000000
# max    323.124000    1.000000

# %% [markdown]
# problem to be solved:
# 1. missing value in ph, both upper level & lower outlier
# 2.  solid with both upper level & lower outlier
# 3.  hardness with both upper level & lower outlier

# %%
#function  for plt
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
plot_boxplot(df,"ph")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['ph'].quantile(0.99)
lower_limit=df['ph'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 12.176515857000009
# lower_limit: 3.4992591227

# %%
#getting the outliers
df.loc[(df['ph']>=upper_limit) | (df['ph']<=lower_limit)]
# Out:
#            date         ph  turbidity        solids  chromium  conductivity  \
# 13     2/3/2018  13.175402   4.106924  19237.949680      0.51    500.245952
# 104   9/23/2018   2.798549   3.663252  26931.243480      0.41    521.140524
# 186   4/20/2019   3.445062   4.184397  33424.768680      1.00    441.785876
# 240    9/3/2019  12.844538   5.013463  28689.595780       NaN    410.387264
# 241    9/6/2019  52.519126   3.758996  12531.601920       NaN    443.570372
# 264   11/3/2019   2.612036   4.765205  34798.252590      1.00    468.080267
# 273  11/29/2019   3.388091   2.798601  20230.125580      1.00    353.912927
# 331   4/23/2020  12.987000   3.310859  21136.286760      1.00    332.737587
# 392   9/26/2020   1.757037   2.967554  41538.242730      0.20    428.444822
# 426  12/20/2020   0.227499   3.545741  39028.599340      0.09    443.029232
# 456    3/3/2021   3.426450   5.978054  21839.695960      0.23    437.377181
# 510   7/20/2021   0.989912   5.160604  16922.853900      0.88    322.291191
# 550  10/30/2021  12.897000   4.238253  20827.983840       NaN    567.604151
# 555   11/9/2021  12.455599   4.476349  37620.248470       NaN    343.417588
# 559  11/23/2021  13.987600   4.456104  28184.900530       NaN    445.700761
# 707   12/1/2022  12.987500   4.071344   3900.913892       NaN    553.494032
#
#        hardness  potability
# 13    47.432000           1
# 104  311.383957           1
# 186  207.926260           0
# 240  233.764343           0
# 241  168.728583           0
# 264  188.804126           0
# 273  212.028944           0
# 331  233.850345           0
# 392  147.581831           1
# 426  152.530111           1
# 456  154.711725           1
# 510  133.216942           1
# 550  209.426837           0
# 555  152.386735           0
# 559  203.050244           0
# 707  235.004598           0

# %%
#using capping method
df.loc[df['ph']>=upper_limit, 'ph']=upper_limit
df.loc[df['ph']<=lower_limit, 'ph']=lower_limit

# %%
plot_boxplot(df,"solids")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['solids'].quantile(0.99)
lower_limit=df['solids'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 45246.485370400005
# lower_limit: 5770.234711109999

# %%
#getting the outliers
df.loc[(df['solids']>=upper_limit) | (df['solids']<=lower_limit)]
# Out:
#            date         ph  turbidity        solids  chromium  conductivity  \
# 33    3/26/2018  10.356119   4.201849  48621.563950      1.00    365.720291
# 37     4/3/2018  10.003301   4.746382  46113.957490      0.74    574.555041
# 116  10/23/2018   4.037288   3.045049  52318.917300      0.02    401.204271
# 124   11/9/2018   8.882684   3.827921   4857.253807      0.15    532.336659
# 128  11/23/2018   6.105140   3.103090  45249.449030      0.09    314.965090
# 155    2/1/2019        NaN   4.120931  46931.884290      0.45    557.421879
# 302    2/9/2020   6.825468   3.027450  46140.126850      1.00    373.427235
# 366   7/20/2020        NaN   2.000757  52060.226800      0.46    323.001036
# 573  12/29/2021   9.953952   4.052905   3773.281147      1.00    339.883029
# 601    3/6/2022   7.344976   3.418763   5689.804405      1.00    360.184473
# 641   6/16/2022        NaN   2.276392   5699.504942      1.00    269.344635
# 651    7/9/2022   9.302441   3.675985   5230.630430      1.00    367.897563
# 668   8/26/2022   7.856471   4.534681   5619.135558      1.00    432.043120
# 687   10/9/2022   4.771491   3.936973  48002.084600      1.00    310.927835
# 707   12/1/2022  12.176516   4.071344   3900.913892       NaN    553.494032
# 730   1/30/2023  11.608534   3.042797   4544.841718       NaN    328.904494
# 758    4/9/2023   8.037430   2.506238  48410.471010      0.68    392.901206
# 812   8/26/2023        NaN   4.081329   2808.025756      0.46    354.405279
# 867    1/9/2024   9.484703   4.132274  56351.396300      0.41    480.848064
# 873   1/26/2024   6.646470   4.387602   5516.874953      0.02    339.208703
#
#        hardness  potability
# 33   136.323752           0
# 37   143.094285           1
# 116  291.461897           1
# 124  135.523062           1
# 128  249.141391           1
# 155  286.201763           1
# 302  187.051710           0
# 366  155.675777           1
# 573  232.949002           0
# 601  182.306942           0
# 641  212.449974           0
# 651  236.580794           0
# 668  204.783428           0
# 687  200.374076           0
# 707  235.004598           0
# 730  231.340228           0
# 758  148.415309           1
# 812  259.144928           1
# 867  122.906991           1
# 873  251.836248           1

# %%
#using capping method
df.loc[df['solids']>=upper_limit, 'solids']=upper_limit
df.loc[df['solids']<=lower_limit, 'solids']=lower_limit

# %%
plot_boxplot(df,"hardness")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['hardness'].quantile(0.99)
lower_limit=df['hardness'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 282.61176298299995
# lower_limit: 112.467964437

# %%
#getting the outliers
df.loc[(df['hardness']>=upper_limit) | (df['hardness']<=lower_limit)]
# Out:
#            date         ph  turbidity       solids  chromium  conductivity  \
# 8     1/23/2018   9.802721   2.764634  27357.45674      0.77    512.428731
# 13     2/3/2018  12.176516   4.106924  19237.94968      0.51    500.245952
# 28     3/9/2018  10.761898   4.661799  25999.95367      0.62    392.704082
# 67    6/20/2018  11.301794   3.309580  39227.61946      1.00    410.856114
# 71    6/30/2018   4.642953   3.982867  16115.92986      0.04    439.944408
# 85     8/3/2018  10.026224   3.736228  25510.09730      0.41    388.467266
# 92    8/23/2018   5.910252   3.660923  15244.84639      0.77    695.369528
# 97     9/3/2018   3.551579   3.965994  38969.38899      0.18    514.762918
# 104   9/23/2018   3.499259   3.663252  26931.24348      0.41    521.140524
# 116  10/23/2018   4.037288   3.045049  45246.48537      0.02    401.204271
# 129  11/26/2018   9.443359   3.486646  20438.22469      0.25    458.677232
# 133   12/6/2018   4.912557   4.897373  44063.09842      0.84    327.475650
# 155    2/1/2019        NaN   4.120931  45246.48537      0.45    557.421879
# 197   5/16/2019   5.618064   2.896547  17281.97517      1.00    399.471566
# 211   6/23/2019   7.809632   2.447444  12013.55063      1.00    605.220124
# 227    8/1/2019        NaN   4.620793  27420.16742      1.00    485.974500
# 248   9/26/2019  10.155440   5.002467  12652.36298      1.00    487.459131
# 309   2/26/2020   5.187472   3.203258  20060.07873      1.00    368.815429
# 347    6/1/2020   8.661592   3.670431  27088.47646      1.00    512.277310
# 349    6/6/2020   6.626012   4.194313  25839.89410      1.00    327.248079
#
#        hardness  potability
# 8     98.771644           1
# 13    47.432000           1
# 28    81.710895           1
# 67    77.459586           0
# 71   307.706024           1
# 85    94.091307           1
# 92   282.739017           1
# 97   323.124000           1
# 104  311.383957           1
# 116  291.461897           1
# 129   73.492234           1
# 133  308.253833           1
# 155  286.201763           1
# 197  304.235912           0
# 211  100.457615           0
# 227  103.464759           0
# 248  300.292476           0
# 309  104.752425           0
# 347  284.098351           0
# 349  112.299486           0

# %%
#using capping method
df.loc[df['hardness']>=upper_limit, 'hardness']=upper_limit
df.loc[df['hardness']<=lower_limit, 'hardness']=lower_limit

# %%
plot_boxplot(df,"chromium")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['chromium'].quantile(0.99)
lower_limit=df['chromium'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 1.0
# lower_limit: 0.02

# %%
#getting the outliers
df.loc[(df['chromium']>=upper_limit) | (df['chromium']<=lower_limit)]
# Out:
#           date         ph  turbidity        solids  chromium  conductivity  \
# 30   3/16/2018   9.794559   2.945419  20682.731740      1.00    427.123948
# 33   3/26/2018  10.356119   4.201849  45246.485370      1.00    365.720291
# 51    5/9/2018  10.049674   5.133478  11557.032040      1.00    442.768050
# 53   5/12/2018        NaN   3.807920  27776.180260      1.00    417.631202
# 54   5/16/2018   8.923981   4.155583  27919.770670      1.00    415.629484
# ..         ...        ...        ...           ...       ...           ...
# 748  3/12/2023   8.746986   4.763731  22174.781140      1.00    407.380825
# 749  3/16/2023   8.154841   3.696328  25620.771370      1.00    597.870073
# 772  5/12/2023        NaN   4.387208  19947.434470      0.01    295.757053
# 873  1/26/2024   6.646470   4.387602   5770.234711      0.02    339.208703
# 890   3/6/2024   7.828740   5.199447  33337.109650      0.02    290.118613
#
#        hardness  potability
# 30   129.870958           0
# 33   136.323752           0
# 51   132.832837           0
# 53   181.689164           0
# 54   135.938468           0
# ..          ...         ...
# 748  148.393724           0
# 749  202.317335           0
# 772  200.315236           1
# 873  251.836248           1
# 890  176.727511           1
#
# [430 rows x 8 columns]

# %%
#using capping method
df.loc[df['chromium']>=upper_limit, 'chromium']=upper_limit
df.loc[df['chromium']<=lower_limit, 'chromium']=lower_limit

# %%
plot_boxplot(df,"conductivity")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['conductivity'].quantile(0.99)
lower_limit=df['conductivity'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 615.3691202849999
# lower_limit: 265.665066582

# %%
#getting the outliers
df.loc[(df['conductivity']>=upper_limit) | (df['conductivity']<=lower_limit)]
# Out:
#            date        ph  turbidity        solids  chromium  conductivity  \
# 24     3/1/2018       NaN   3.772919  16146.157110      0.13    629.281247
# 92    8/23/2018  5.910252   3.660923  15244.846390      0.77    695.369528
# 117  10/26/2018  6.505873   4.497529  29534.690290      0.33    265.251199
# 226   7/30/2019  5.058109   5.106656  34873.934520      1.00    669.725086
# 268  11/12/2019  6.098157   3.977362  27776.901050      1.00    245.859632
# 275   12/1/2019       NaN   5.629016  28062.641890      1.00    263.771913
# 300    2/3/2020  8.594416   3.568992  15791.675350      1.00    672.556999
# 312    3/3/2020  6.579969   4.575932  17657.084180      1.00    254.393276
# 337    5/6/2020       NaN   3.665522  19517.724800      1.00    251.020899
# 345   5/30/2020  9.534022   2.768239   9472.614920      1.00    259.636803
# 369   7/29/2020       NaN   2.475284  29496.910160      0.89    616.175243
# 383    9/1/2020  4.595608   3.978920  13891.038530      0.73    631.822078
# 447   2/12/2021  7.702183   4.382159  18126.030960      0.09    646.732599
# 477   4/29/2021  8.589202   4.041446   7263.056749      0.54    258.880209
# 588    2/3/2022  7.183096   3.806539  13501.677970      1.00    617.540907
# 625    5/6/2022  7.602121   3.698875  11346.143450      1.00    210.319182
# 700  11/12/2022  6.648849   4.827527  30733.503840      1.00    257.704179
# 712  12/12/2022  7.581688   4.457282  11989.246240      1.00    617.883513
# 776   5/26/2023  4.187491   4.592959  21809.709830      0.39    264.508083
# 864    1/1/2024  7.064789   4.401628  20567.145930      0.84    656.924128
#
#        hardness  potability
# 24   156.520635           1
# 92   282.611763           1
# 117  240.287912           1
# 226  238.569380           0
# 268  189.995846           0
# 275  190.423899           0
# 300  270.022706           0
# 312  197.226981           0
# 337  260.205360           0
# 345  201.955208           0
# 369  186.595255           1
# 383  204.859660           1
# 447  192.137531           1
# 477  233.727975           1
# 588  200.368159           0
# 625  199.353165           0
# 700  181.688122           0
# 712  180.749140           0
# 776  208.374188           1
# 864  188.391725           1

# %%
#using capping method
df.loc[df['conductivity']>=upper_limit, 'conductivity']=upper_limit
df.loc[df['conductivity']<=lower_limit, 'conductivity']=lower_limit

# %%
plot_boxplot(df,"turbidity")

# %%
#using percentile method to get the upper_liit and lower_limit
upper_limit=df['turbidity'].quantile(0.99)
lower_limit=df['turbidity'].quantile(0.01)

print('upper_limit:', upper_limit)
print('lower_limit:', lower_limit)
# Out:
# upper_limit: 5.71217619652
# lower_limit: 2.18275083505

# %%
#getting the outliers
df.loc[(df['turbidity']>=upper_limit) | (df['turbidity']<=lower_limit)]
# Out:
#            date         ph  turbidity        solids  chromium  conductivity  \
# 17    2/15/2018   5.626340   1.943319  14442.418880      0.88    346.553206
# 70    6/29/2018        NaN   5.922582  14507.017810      1.00    290.889472
# 132   12/3/2018   5.772718   6.494249  26124.931410      0.32    465.559286
# 189   4/29/2019        NaN   6.038185  15193.413470      1.00    563.804743
# 253   10/6/2019   9.026788   2.019042  27965.072150      1.00    588.319650
# 279   12/9/2019   7.812804   6.204846  42550.841820      1.00    442.545774
# 315    3/9/2020   6.906992   2.124759  19991.239150      1.00    356.459137
# 358   6/30/2020   5.554437   2.095914  31344.460390      1.00    306.872526
# 366   7/20/2020        NaN   2.000757  45246.485370      0.46    323.001036
# 399   10/9/2020   7.376449   5.767355  37191.114140      0.73    439.312853
# 428  12/26/2020   7.110845   5.712792  25043.532800      0.61    505.735535
# 456    3/3/2021   3.499259   5.978054  21839.695960      0.23    437.377181
# 489   5/30/2021   5.361212   1.812529  24709.728860      0.55    490.658747
# 677   9/16/2022   6.669532   1.964863  16246.173190      1.00    383.245825
# 690  10/20/2022   5.477283   6.357439  29046.083520      1.00    488.774595
# 736   2/15/2023  11.368126   2.004143  32619.312970       NaN    435.666469
# 740   2/24/2023   5.499489   5.846827  13902.968650      1.00    442.167006
# 754   3/30/2023   7.203439   6.389161  22826.484700      0.20    437.370863
# 804    8/3/2023   5.803497   2.181714  19451.767600      0.04    365.477618
# 832  10/12/2023   4.303575   2.010537   7323.302301      0.82    412.896404
#
#        hardness  potability
# 17   230.857983           1
# 70   144.815264           0
# 132  213.363545           1
# 189  148.153061           0
# 253  253.217074           0
# 279  196.583886           0
# 315  216.785291           0
# 358  229.122829           0
# 366  155.675777           1
# 399  168.750007           1
# 428  213.886337           1
# 456  154.711725           1
# 489  171.315543           1
# 677  190.751165           0
# 690  165.436093           0
# 736  190.937979           0
# 740  230.308775           0
# 754  168.445358           1
# 804  193.200991           1
# 832  227.007086           1

# %%
#using capping method
df.loc[df['turbidity']>=upper_limit, 'turbidity']=upper_limit
df.loc[df['turbidity']<=lower_limit, 'turbidity']=lower_limit

# %%
df.describe()
# Out:
#                ph   turbidity        solids    chromium  conductivity  \
# count  779.000000  912.000000    912.000000  873.000000    912.000000
# mean     7.283906    3.943342  22107.008862    0.718751    426.560319
# std      1.850466    0.772897   8742.772179    0.328923     80.493110
# min      3.499259    2.182751   5770.234711    0.020000    265.665067
# 25%      5.996849    3.421016  15338.539553    0.460000    364.512390
# 50%      7.160467    3.938100  21284.713075    0.880000    421.086049
# 75%      8.335468    4.475458  27776.360457    1.000000    482.607998
# max     12.176516    5.712176  45246.485370    1.000000    615.369120
#
#          hardness  potability
# count  912.000000  912.000000
# mean   198.050821    0.512061
# std     32.818950    0.500129
# min    112.467964    0.000000
# 25%    178.213958    0.000000
# 50%    199.067577    1.000000
# 75%    218.243182    1.000000
# max    282.611763    1.000000

# %%
#missing values for ph and chromium

df.ph=df.ph.fillna(df.ph.mean())
df.chromium=df.chromium.fillna(df.chromium.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          912 non-null    object
#  1   ph            912 non-null    float64
#  2   turbidity     912 non-null    float64
#  3   solids        912 non-null    float64
#  4   chromium      912 non-null    float64
#  5   conductivity  912 non-null    float64
#  6   hardness      912 non-null    float64
#  7   potability    912 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 57.1+ KB

# %%
#dropping of Date

df=df.drop(['date'],axis=1)

# %%
#checking for the correlation field
df.corr()
# Out:
#                     ph  turbidity    solids  chromium  conductivity  hardness  \
# ph            1.000000  -0.021646 -0.153469  0.020666      0.024244 -0.056119
# turbidity    -0.021646   1.000000  0.034845  0.009239     -0.024584 -0.050480
# solids       -0.153469   0.034845  1.000000 -0.002705      0.011328 -0.163927
# chromium      0.020666   0.009239 -0.002705  1.000000     -0.031327 -0.022756
# conductivity  0.024244  -0.024584  0.011328 -0.031327      1.000000 -0.069545
# hardness     -0.056119  -0.050480 -0.163927 -0.022756     -0.069545  1.000000
# potability   -0.092723   0.015325  0.016199 -0.801812     -0.001795  0.007326
#
#               potability
# ph             -0.092723
# turbidity       0.015325
# solids          0.016199
# chromium       -0.801812
# conductivity   -0.001795
# hardness        0.007326
# potability      1.000000

# %%
#data spliting
y = df.iloc[:, -1].values
X =df.drop(["potability","conductivity","hardness","turbidity"],axis=1).values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# using GaussianNB model
Gaussian_classifier = GaussianNB()


Gaussian_classifier.fit(X_train,y_train)
y_pred=Gaussian_classifier.predict(X_test)
Accuracy=accuracy_score(y_test, y_pred)
print(f'The model has {round(100 * Accuracy,2)}% of accuracy')
# Out:
# The model has 90.16% of accuracy

# %%
Conf_mx=confusion_matrix(y_test, y_pred)
class_names = ['Not safe', 'safe']
plt.figure(figsize=(10, 7))
sn.heatmap(Conf_mx, fmt='.2f', square=True, linecolor='white', annot=True, cmap="coolwarm", xticklabels=class_names, yticklabels=class_names);
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# using logistic model
Logistic_classifier = LogisticRegression()


Logistic_classifier.fit(X_train,y_train)
y_pred=Logistic_classifier.predict(X_test)
Accuracy=accuracy_score(y_test, y_pred)
conf_mx=confusion_matrix(y_test, y_pred)
print(Accuracy)
print(conf_mx)
# Out:
# 0.4808743169398907
# [[ 0 95]
#  [ 0 88]]
